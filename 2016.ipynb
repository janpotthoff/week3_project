# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('2016.csv')
data
# Out:
#                   Country                           Region  Happiness Rank  \
# 0                 Denmark                   Western Europe               1
# 1             Switzerland                   Western Europe               2
# 2                 Iceland                   Western Europe               3
# 3                  Norway                   Western Europe               4
# 4                 Finland                   Western Europe               5
# 5                  Canada                    North America               6
# 6             Netherlands                   Western Europe               7
# 7             New Zealand        Australia and New Zealand               8
# 8               Australia        Australia and New Zealand               9
# 9                  Sweden                   Western Europe              10
# 10                 Israel  Middle East and Northern Africa              11
# ...

# %%
data2 = data.drop(['Lower Confidence Interval', 'Upper Confidence Interval', 'Region'], axis=1)
data2.head(20)
# Out:
#           Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0         Denmark               1            7.526                   1.44178
# 1     Switzerland               2            7.509                   1.52733
# 2         Iceland               3            7.501                   1.42666
# 3          Norway               4            7.498                   1.57744
# 4         Finland               5            7.413                   1.40598
# 5          Canada               6            7.404                   1.44015
# 6     Netherlands               7            7.339                   1.46468
# 7     New Zealand               8            7.334                   1.36066
# 8       Australia               9            7.313                   1.44443
# 9          Sweden              10            7.291                   1.45181
# 10         Israel              11            7.267                   1.33766
# ...

# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
# Read data
suicide_all = pd.read_csv('master.csv')
suicide_all.tail(20)
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27800  Uzbekistan  2013    male  55-74 years          119     1202790
# 27801  Uzbekistan  2013    male    75+ years           13      221002
# 27802  Uzbekistan  2013  female  25-34 years          146     2647820
# 27803  Uzbekistan  2013  female  35-54 years           99     3547895
# 27804  Uzbekistan  2013  female    75+ years            8      345180
# 27805  Uzbekistan  2013    male   5-14 years           61     2720938
# 27806  Uzbekistan  2013  female  55-74 years           21     1356298
# 27807  Uzbekistan  2013  female   5-14 years           31     2595000
# 27808  Uzbekistan  2014    male  35-54 years          519     3421300
# 27809  Uzbekistan  2014    male  25-34 years          318     2739150
# 27810  Uzbekistan  2014  female  15-24 years          347     2992817
# 27811  Uzbekistan  2014    male  55-74 years          144     1271111
# 27812  Uzbekistan  2014    male  15-24 years          347     3126905
# 27813  Uzbekistan  2014    male    75+ years           17      224995
# 27814  Uzbekistan  2014  female  25-34 years          162     2735238
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 27800               9.89  Uzbekistan2013         0.672     57,690,453,461
# 27801               5.88  Uzbekistan2013         0.672     57,690,453,461
# 27802               5.51  Uzbekistan2013         0.672     57,690,453,461
# 27803               2.79  Uzbekistan2013         0.672     57,690,453,461
# 27804               2.32  Uzbekistan2013         0.672     57,690,453,461
# 27805               2.24  Uzbekistan2013         0.672     57,690,453,461
# 27806               1.55  Uzbekistan2013         0.672     57,690,453,461
# 27807               1.19  Uzbekistan2013         0.672     57,690,453,461
# 27808              15.17  Uzbekistan2014         0.675     63,067,077,179
# 27809              11.61  Uzbekistan2014         0.675     63,067,077,179
# 27810              11.59  Uzbekistan2014         0.675     63,067,077,179
# 27811              11.33  Uzbekistan2014         0.675     63,067,077,179
# 27812              11.10  Uzbekistan2014         0.675     63,067,077,179
# 27813               7.56  Uzbekistan2014         0.675     63,067,077,179
# 27814               5.92  Uzbekistan2014         0.675     63,067,077,179
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)    generation
# 27800                2150       Boomers
# 27801                2150        Silent
# 27802                2150    Millenials
# 27803                2150  Generation X
# 27804                2150        Silent
# 27805                2150  Generation Z
# 27806                2150       Boomers
# 27807                2150  Generation Z
# 27808                2309  Generation X
# 27809                2309    Millenials
# 27810                2309    Millenials
# 27811                2309       Boomers
# 27812                2309    Millenials
# 27813                2309        Silent
# 27814                2309    Millenials
# 27815                2309  Generation X
# 27816                2309        Silent
# 27817                2309  Generation Z
# 27818                2309  Generation Z
# 27819                2309       Boomers

# %%
suicide_all.shape
# Out:
# (27820, 12)

# %%
nulls = suicide_all.isnull().sum()
nulls
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
year = suicide_all[(2014<(suicide_all['year']))]
refine1 = year.drop(columns=['HDI for year','generation','country-year'])
year2 = suicide_all[(2014==(suicide_all['year']))]
refine2 = year2.drop(columns=['HDI for year','generation','country-year'])
refine1.head(20)
# Out:
#                  country  year     sex          age  suicides_no  population  \
# 576  Antigua and Barbuda  2015  female  55-74 years            1        6403
# 577  Antigua and Barbuda  2015  female  15-24 years            0        8561
# 578  Antigua and Barbuda  2015  female  25-34 years            0        7740
# 579  Antigua and Barbuda  2015  female  35-54 years            0       15323
# 580  Antigua and Barbuda  2015  female   5-14 years            0        8239
# 581  Antigua and Barbuda  2015  female    75+ years            0        1724
# 582  Antigua and Barbuda  2015    male  15-24 years            0        8331
# 583  Antigua and Barbuda  2015    male  25-34 years            0        7059
# 584  Antigua and Barbuda  2015    male  35-54 years            0       13370
# 585  Antigua and Barbuda  2015    male   5-14 years            0        8268
# 586  Antigua and Barbuda  2015    male  55-74 years            0        5784
# 587  Antigua and Barbuda  2015    male    75+ years            0        1087
# 948            Argentina  2015    male    75+ years          245      712691
# 949            Argentina  2015    male  15-24 years          656     3500580
# 950            Argentina  2015    male  55-74 years          431     3011963
# 951            Argentina  2015    male  25-34 years          465     3289927
# 952            Argentina  2015    male  35-54 years          633     5166179
# 953            Argentina  2015  female  15-24 years          153     3394201
# 954            Argentina  2015  female  55-74 years          125     3520779
# 955            Argentina  2015  female  25-34 years          114     3235582
#
#      suicides/100k pop  gdp_for_year ($)   gdp_per_capita ($)
# 576              15.62      1,364,863,037               14853
# 577               0.00      1,364,863,037               14853
# 578               0.00      1,364,863,037               14853
# 579               0.00      1,364,863,037               14853
# 580               0.00      1,364,863,037               14853
# 581               0.00      1,364,863,037               14853
# 582               0.00      1,364,863,037               14853
# 583               0.00      1,364,863,037               14853
# 584               0.00      1,364,863,037               14853
# 585               0.00      1,364,863,037               14853
# 586               0.00      1,364,863,037               14853
# 587               0.00      1,364,863,037               14853
# 948              34.38    594,749,285,413               14981
# 949              18.74    594,749,285,413               14981
# 950              14.31    594,749,285,413               14981
# 951              14.13    594,749,285,413               14981
# 952              12.25    594,749,285,413               14981
# 953               4.51    594,749,285,413               14981
# 954               3.55    594,749,285,413               14981
# 955               3.52    594,749,285,413               14981

# %%
countries = set(year['country'])
countries2 = set(year2['country'])
print((countries))
print((countries2))
# Out:
# {'Antigua and Barbuda', 'Seychelles', 'Austria', 'United States', 'Greece', 'Malta', 'Netherlands', 'Uruguay', 'Colombia', 'Serbia', 'Ukraine', 'United Kingdom', 'Chile', 'Brazil', 'Latvia', 'Romania', 'Czech Republic', 'Denmark', 'Luxembourg', 'Turkmenistan', 'Turkey', 'Mongolia', 'Republic of Korea', 'Mexico', 'Spain', 'Qatar', 'Panama', 'Argentina', 'South Africa', 'Armenia', 'Italy', 'Georgia', 'Kyrgyzstan', 'Singapore', 'Guatemala', 'Estonia', 'Norway', 'Kazakhstan', 'Belgium', 'Germany', 'Grenada', 'Lithuania', 'Nicaragua', 'Russian Federation', 'Cuba', 'Puerto Rico', 'Cyprus', 'Iceland', 'Australia', 'Ecuador', 'Switzerland', 'Poland', 'Croatia', 'Mauritius', 'Saint Vincent and Grenadines', 'Hungary', 'Sweden', 'Slovenia', 'Israel', 'Thailand', 'Finland', 'Japan', 'Belize'}
# {'Antigua and Barbuda', 'Seychelles', 'Austria', 'United States', 'Greece', 'Malta', 'Netherlands', 'Uruguay', 'Kuwait', 'Bulgaria', 'Colombia', 'Serbia', 'Ukraine', 'Chile', 'United Kingdom', 'Brazil', 'Costa Rica', 'Latvia', 'Bahrain', 'Paraguay', 'Romania', 'Czech Republic', 'Denmark', 'Luxembourg', 'Slovakia', 'Turkmenistan', 'Uzbekistan', 'Turkey', 'Suriname', 'Republic of Korea', 'Mexico', 'Spain', 'Ireland', 'Panama', 'Portugal', 'Argentina', 'Qatar', 'Armenia', 'Italy', 'Georgia', 'Kyrgyzstan', 'Singapore', 'South Africa', 'Bosnia and Herzegovina', 'Guatemala', 'Estonia', 'Norway', 'Kazakhstan', 'Belgium', 'Germany', 'Grenada', 'Lithuania', 'Nicaragua', 'Russian Federation', 'Saint Lucia', 'Cuba', 'Puerto Rico', 'Cyprus', 'Iceland', 'El Salvador', 'Australia', 'Ecuador', 'France', 'Switzerland', 'Poland', 'Croatia', 'Mauritius', 'Oman', 'Saint Vincent and Grenadines', 'Belarus', 'Hungary', 'Sweden', 'Slovenia', 'Israel', 'Thailand', 'Finland', 'Japan', 'Belize'}

# %%
collapse1 = refine1.drop(columns=['sex','age'])
collapse1 = collapse1.rename(columns={'gdp_for_year ($)':'gdp USD', 'gdp_per_capita ($)':'gdp_per_capita USD'})
collapse1 = collapse1.groupby(['country', 'year','gdp_per_capita USD'], as_index=False).agg({'suicides_no':'sum', 'population':'sum', 'suicides/100k pop':'mean'})
collapse1.head(10)
# Out:
#                country  year  gdp_per_capita USD  suicides_no  population  \
# 0  Antigua and Barbuda  2015               14853            1       91889
# 1            Argentina  2015               14981         3073    39699624
# 2              Armenia  2015                3775           74     2795335
# 3              Armenia  2016                3788           67     2400033
# 4            Australia  2015               60656         3027    22240785
# 5              Austria  2015               46484         1251     8219386
# 6              Austria  2016               46976         1201     7484629
# 7              Belgium  2015               42830         1867    10624356
# 8               Belize  2015                5561           26      319835
# 9               Brazil  2015                9431        11163   191087085
#
#    suicides/100k pop
# 0           1.301667
# 1           9.344167
# 2           3.773333
# 3           4.056000
# 4          12.848333
# 5          16.218333
# 6          18.323000
# 7          16.388333
# 8          11.288333
# 9           6.454167

# %%
collapse1 = collapse1.groupby(['country', 'year','gdp_per_capita USD'], as_index=False).agg({'suicides_no':'sum', 'population':'sum', 'suicides/100k pop':'mean'})
collapse1
# Out:
#                 country  year  gdp_per_capita USD  suicides_no  population  \
# 0   Antigua and Barbuda  2015               14853            1       91889
# 1             Argentina  2015               14981         3073    39699624
# 2               Armenia  2015                3775           74     2795335
# 3               Armenia  2016                3788           67     2400033
# 4             Australia  2015               60656         3027    22240785
# ..                  ...   ...                 ...          ...         ...
# 73         Turkmenistan  2015                7326          133     4886514
# 74              Ukraine  2015                2256         7574    40345446
# 75       United Kingdom  2015               47240         4910    61082942
# 76        United States  2015               60387        44189   300078511
# 77              Uruguay  2015               16696          630     3190795
#
#     suicides/100k pop
# 0            1.301667
# 1            9.344167
# 2            3.773333
# 3            4.056000
# 4           12.848333
# ..                ...
# 73           2.373333
# 74          20.393333
# 75           7.228333
# 76          14.617500
# 77          22.501667
#
# [78 rows x 6 columns]

# %%
collapse2 = refine2.drop(columns=['sex','age'])
collapse2 = collapse2.rename(columns={'gdp_for_year ($)':'gdp USD', 'gdp_per_capita ($)':'gdp_per_capita USD'})
collapse2 = collapse2.groupby(['country', 'year','gdp_per_capita USD'], as_index=False).agg({'suicides_no':'sum', 'population':'sum', 'suicides/100k pop':'mean'})

collapse2 = collapse2.groupby(['country', 'year','gdp_per_capita USD'], as_index=False).agg({'suicides_no':'sum', 'population':'sum', 'suicides/100k pop':'mean'})
collapse2
# Out:
#                 country  year  gdp_per_capita USD  suicides_no  population  \
# 0   Antigua and Barbuda  2014               14093            0       90837
# 1             Argentina  2014               13400         3231    39276555
# 2               Armenia  2014                4142           58     2803029
# 3             Australia  2014               66809         2891    21927587
# 4               Austria  2014               54278         1314     8141165
# ..                  ...   ...                 ...          ...         ...
# 73              Ukraine  2014                3299         7968    40464165
# 74       United Kingdom  2014               49906         4788    60570482
# 75        United States  2014               58531        42769   297749735
# 76              Uruguay  2014               18012          591     3177645
# 77           Uzbekistan  2014                2309         2095    27313507
#
#     suicides/100k pop
# 0            0.000000
# 1            9.279167
# 2            3.084167
# 3           12.422500
# 4           17.485000
# ..                ...
# 73          20.875000
# 74           6.994167
# 75          14.277500
# 76          20.720000
# 77           7.093333
#
# [78 rows x 6 columns]
